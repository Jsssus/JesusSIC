# %% [markdown]
# # Cap 7. Tratamiento de datos, estadística descriptiva y visualización de datos
#
# ## Unit 34. Uso de módulos de Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Obtener tiempo actual

import time

t_act = time.time() # 1 de enero de 1970, 00:00:00 UTC ## The epoch is the point where the time starts
# La época actual del 1 de enero de 1970 a las 00:00:00 UTC fue seleccionada arbitrariamente por los 
#ingenieros de Unix porque se consideró una fecha conveniente para trabajar 
print("Tiempo actual en segundos", t_act)
# Out:
# Tiempo actual en segundos 1730851075.2105434

# %%
# Conversión de tiempo

import time

seg = 1709680821.2168674
t_tupla = time.gmtime(seg)
print("Tiempo en formato de tupla", t_tupla)
# Out:
# Tiempo en un formato utilizable:  time.struct_time(tm_year=2024, tm_mon=11, tm_mday=5, tm_hour=23, tm_min=28, tm_sec=26, tm_wday=1, tm_yday=310, tm_isdst=0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Manipulación del objeto datetime
import datetime

f_act = datetime.datetime.now()

print("Año: ", f_act.year)
print("Mes: ", f_act.month)
print("Día: ", f_act.day)
print("Hora: ", f_act.hour)
print("Minuto: ", f_act.minute)
print("Segundo: ", f_act.second)

# Sumar una fecha futura
print("_____________")
duracion = datetime.timedelta(days=7)
f_futura = f_act + duracion
print("Fecha dentro de una semana: ", f_futura)

# Reemplazar año y mes
print("_____________")
f_modf = f_act.replace(year=2025, month=8)
print("Fecha modificada: ", f_modf)

# Formato a un obj datetime
print("_____________")
print("Objeto Date time", f_act)
f_formato = f_act.strftime("%d-%m-%Y %H:%M:%S")
print("Fecha con formato: ", f_formato)

# Pasar una str a un obj datetime
f_str = "2025-01-16"
f_obj = datetime.datetime.strptime(f_str, "%Y-%m-%d")
print("Fecha objeto: ", f_obj)
# Out:
# 2024-11-05 19:47:26.772773
# Año:  2024
# Mes:  11
# Día:  5
# Hora:  19
# Minuto:  47
# Segundo:  26
# ____________________________________________
# Fecha dentro de una semana:  2024-11-12 19:47:26.772773
# _______________________________________________________
# Fecha modificada:  2025-08-05 19:47:26.772773
# _______________________________________________________
# Objeto Date time 2024-11-05 19:47:26.772773
# Fecha con formato:  05/11/2024 - 19:47:26
# _______________________________________________________
# Fecha objeto:  2025-01-16 00:00:00

# %%
import time

## Uso de ctime
t_seg = time.time()
f_h_legible = time.ctime(t_seg)
print("Fecha y hora legibles: ", f_h_legible)

## Uso de gmtime
print("_____________")
t_utc = time.gmtime(t_seg)
print("Tiempo en UTC: ", t_utc)
# Out:
# Fecha y hora legibles:  Tue Nov  5 19:28:26 2024
# _______________________________________________________
# Tiempo en UTC:  time.struct_time(tm_year=2024, tm_mon=11, tm_mday=5, tm_hour=23, tm_min=28, tm_sec=26, tm_wday=1, tm_yday=310, tm_isdst=0)

# %%
# turtle

import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       4 x = np.random.normal(170, 10, 250)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
'''
# Archivo .py que se incluye como módulo en el siguiente código.
# cal_n.py

def sum_n(n):
    return n * (n+1) // 2

def sum_n2(n):
    t = 0
    for i in range(i, n+1):
        t = t+i
    return t
'''

# %%
import calc_n as cl

def main():
    n = int(input('Introduzca num para la suma: '))
    
    sum1 = cl.sum_n2(n)
    print("La suma desde 1 hasta", n, "es: ", sum1)
    
main()
# Out:
# Hola!
# Introduzca num para la suma: 4
# La suma desde 1 hasta 4 es:  6

# %% [markdown]
# ## Unidad 35. Serie Pandas para tratamiento de datos

# %% [markdown]
# La lista de funciones de pandas https://Pandas.pydata.org/
#
# - .xlx
# - .xls
# - .xlsx
#
# - .csv

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Dependencias opcionales
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Estadísticas descriptivas accesibles
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd

pd.__version__
# Out:
# '2.2.3'

# %%
import pandas as pd

s = pd.Series([5,6,7,8])

print(s)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
import pandas as pd

s = pd.Series([5,6,7,8], index=["uno",5,4.0,True])

print(s)
# Out:
# uno     5
# 5       6
# 4.0     7
# True    8
# dtype: int64

# %%
import pandas as pd 

paises = ["Rep. Dominicana", "Venezuela", "Colombia", "Francia", "Italia"]

s = pd.Series(paises)

print(s)
# Out:
# 0       Canada
# 1        EE.UU
# 2    Argentina
# dtype: object

# %%
import pandas as pd 

paises = {"Rep. Dominicana":"Santo Domingo", "Venezuela": "Caracas", "Colombia": "Bogota", "Francia": "Paris", "Italia":"Roma"}

s = pd.Series(paises)

print(s)
print("____")

print(s["Colombia"])
print(s[2])
# Out:
# Canada              Otawa
# EE.UU          Washintong
# Argentina    Buenos Aires
# dtype: object
# _______________________________________________________
# Washintong
# Washintong
# /tmp/ipykernel_28495/2410146842.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[1])

# %%
import pandas as pd
import numpy as np

n = np.arange(10,16)
print(n)

s = pd.Series(n)
print(s)
# Out:
# [10 11 12 13 14 15]
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int64

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

fechas = pd.date_range('2024-01-16','2024-02-01',freq="3D")
# print(fechas)
elem = np.random.random(size=6)

s = pd.Series(elem, index=[fechas])

print(s)
print(s.index)
print(s.values)
# Out:
# 2024-11-05    0.394931
# 2024-11-08    0.339437
# 2024-11-11    0.467934
# 2024-11-14    0.734948
# 2024-11-17    0.448526
# dtype: float64
# MultiIndex([('2024-11-05',),
#             ('2024-11-08',),
#             ('2024-11-11',),
#             ('2024-11-14',),
#             ('2024-11-17',)],
#            )
# [0.39493085 0.33943708 0.46793368 0.73494778 0.44852638]

# %%
import pandas as pd

s = pd.Series(4)
print(s)
# Out:
# 0    4
# dtype: int64

# %%
import pandas as pd
import numpy as np

l1 = [6,7,8,9]
l2 = np.arange(10,15)
s1 = pd.Series(l1)
s2 = pd.Series(l2)

print('Serie 1')
print(s1)
print('Serie 2')
print(s2)

s3 = s1 + s2
print('Suma de series')
print(s3)

print('_____________')

print('Potencia de elementos')
print(s1**2)
# Out:
# Serie 1
# 0    6
# 1    7
# 2    8
# 3    9
# dtype: int64
# Serie 2
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64
# _______________________________________________________
# Suma de series
# 0    16.0
# 1    18.0
# 2    20.0
# 3    22.0
# 4     NaN
# dtype: float64
# _______________________________________________________
# Potencia de elementos
# 0    36
# 1    49
# 2    64
# 3    81
# dtype: int64

# %% [markdown]
# ### Gráficas

# %%
import matplotlib.pyplot as plt

plt.plot([0,1,2,3,4])
plt.show()

# %%
# puntos(     [x]   ,    [y]     )
plt.plot([0,1,2,3,4], [0,1,4,9,16])
plt.show()

# %%
x = range(100)

# y = []
# for i in range(100):
#     y[i] == i**2
    
y = [ i**2 for i in x ]

plt.plot(x, y, linewidth=6.0, color='blue')
plt.title('Gráfica de x^2')
plt.xlabel('Entradas')
plt.ylabel('Salidas')

plt.show()

# %%
import numpy as np
y = np.random.normal(loc=0.5, scale=0.4, size=6)
plt.plot([0,1.5,2,3,4,5],y, scalex=True, scaley=True)
plt.show()

# %% [markdown]
# ## Unidad 36. Pandas DataFrame para el procesamiento de datos

# %% [markdown]
# ### DataFrame
#
# Estructura de datos de etiquetas bidimensional formada por filas y columnas (datos tabulares y hojas de cálculo Excel en analisis de datos).
#
# - Fila representa cada registro (caso)
# - Columna representa una característica (variable).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = {"col1":[2,3,5,6,7], "col2":[6,8,3,5,9]}
s = pd.Series(data)
s
# Out:
# col1    [2, 3, 5, 6, 7]
# col2    [6, 8, 3, 5, 9]
# dtype: object

# %%
import pandas as pd

data = {"col1":[2,3,5,6,7], "col2":[6,8,3,5,9]}

pd.DataFrame(data)
# Out:
#    col1  col2
# 0     2     6
# 1     3     8
# 2     5     3
# 3     6     5
# 4     7     9

# %%
s1 = pd.Series([2,3,5,6,7], index=["a","b","c","d","e"])
s2 = pd.Series([6,8,3,5,9], index=["a","b","c","d","e"])
print(s1); print()
print(s2); print()

data = {'s1':s1, 's2':s2}
df = pd.DataFrame(data)
df
# Out:
# a    2
# b    3
# c    5
# d    6
# e    7
# dtype: int64
#
# a    6
# b    8
# c    3
# d    5
# e    9
# dtype: int64
#    s1  s2
# a   2   6
# b   3   8
# c   5   3
# d   6   5
# e   7   9

# %%
df.index = ["n1","n2","n3","n4","n5"]
df.columns = ["saldo1", "saldo2"]
df
# Out:
#     saldo1  saldo2
# n1       2       6
# n2       3       8
# n3       5       3
# n4       6       5
# n5       7       9

# %%
df.rename(index={"n1":"edad"}, inplace=True)
df.rename(columns={"saldo1":"Jugador1", "saldo2":"Jugador2"}, inplace=True)

# %%
df
# Out:
#       Jugador1  Jugador2
# edad         2         6
# n2           3         8
# n3           5         3
# n4           6         5
# n5           7         9

# %%
print("Shape", df.shape)
print("len", len(df))
print('Index', df.index)
print('Columnas', df.columns)
print('Valores', df.values)
# Out:
# Shape (5, 2)
# len 5
# Index Index(['edad', 'n2', 'n3', 'n4', 'n5'], dtype='object')
# Columnas Index(['Jugador1', 'Jugador2'], dtype='object')
# Valores [[2 6]
#  [3 8]
#  [5 3]
#  [6 5]
#  [7 9]]

# %% [markdown]
# #### Trabajando con un csv

# %%
import pandas as pd
# https://www.kaggle.com/c/titanic/data?select=train.csv

file = 'titanic-train.csv'
df = pd.read_csv(file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
print("index", df.index)
# Out:
# index RangeIndex(start=0, stop=891, step=1)

# %%
print("Columnas: ", df.columns)
# Out:
# Columnas:  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
names = df['Name']

df.index = names

df.head(5)
# Out:
#                                                     PassengerId  ...  Embarked
# Name                                                             ...
# Braund, Mr. Owen Harris                                       1  ...         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  ...         C
# Heikkinen, Miss. Laina                                        3  ...         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4  ...         S
# Allen, Mr. William Henry                                      5  ...         S
#
# [5 rows x 12 columns]

# %%
df.rename(columns={'PassengerId':'pId'}, inplace=True)
df.head()
# Out:
#                                                     pId  ...  Cabin
# Name                                                     ...
# Braund, Mr. Owen Harris                               1  ...    NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2  ...    C85
# Heikkinen, Miss. Laina                                3  ...    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4  ...   C123
# Allen, Mr. William Henry                              5  ...    NaN
#
# [5 rows x 10 columns]

# %%
############## .drop() para borrar ##############
## filas -> axis=0; columnas -> axis=1

df = df.drop(['Name','Embarked'], axis=1)

# %%
#df.head()

# %%
df.drop(['Braund, Mr. Owen Harris'], axis=0, inplace=True)
df.head()
# Out:
#                                                     pId  ...  Cabin
# Name                                                     ...
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2  ...    C85
# Heikkinen, Miss. Laina                                3  ...    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4  ...   C123
# Allen, Mr. William Henry                              5  ...    NaN
# Moran, Mr. James                                      6  ...    NaN
#
# [5 rows x 10 columns]

# %%
df.drop(['pId'], axis=1).iloc[:3]
# Out:
#                                                     Survived  ...  Cabin
# Name                                                          ...
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  ...    C85
# Heikkinen, Miss. Laina                                     1  ...    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1  ...   C123
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### df.head()

# %%
# df.drop(['pId', axis=1], inplace=True)
df = df.drop(['pId'], axis=1)

# %%
df.columns[6]
# Out:
# 'Ticket'

# %%
df.iloc[1:9]
# Out:
#                                                    Survived  ...  Cabin
# Name                                                         ...
# Heikkinen, Miss. Laina                                    1  ...    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              1  ...   C123
# Allen, Mr. William Henry                                  0  ...    NaN
# Moran, Mr. James                                          0  ...    NaN
# McCarthy, Mr. Timothy J                                   0  ...    E46
# Palsson, Master. Gosta Leonard                            0  ...    NaN
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  ...    NaN
# Nasser, Mrs. Nicholas (Adele Achem)                       1  ...    NaN
#
# [8 rows x 9 columns]

# %%
df.loc[['Heikkinen, Miss. Laina','Moran, Mr. James']]
# Out:
#                         Survived  Pclass  ...    Fare  Cabin
# Name                                      ...
# Heikkinen, Miss. Laina         1       3  ...  7.9250    NaN
# Moran, Mr. James               0       3  ...  8.4583    NaN
#
# [2 rows x 9 columns]

# %%
new_df = df.iloc[1:6]
new_df.head()
# Out:
#                                               Survived  Pclass  ...     Fare  Cabin
# Name                                                            ...
# Heikkinen, Miss. Laina                               1       3  ...   7.9250    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  ...  53.1000   C123
# Allen, Mr. William Henry                             0       3  ...   8.0500    NaN
# Moran, Mr. James                                     0       3  ...   8.4583    NaN
# McCarthy, Mr. Timothy J                              0       1  ...  51.8625    E46
#
# [5 rows x 9 columns]

# %%
new_df.describe()
# Out:
#        Survived    Pclass        Age     SibSp  Parch       Fare
# count  5.000000  5.000000   4.000000  5.000000    5.0   5.000000
# mean   0.400000  2.200000  37.500000  0.200000    0.0  25.879160
# std    0.547723  1.095445  11.789826  0.447214    0.0  24.289016
# min    0.000000  1.000000  26.000000  0.000000    0.0   7.925000
# 25%    0.000000  1.000000  32.750000  0.000000    0.0   8.050000
# 50%    0.000000  3.000000  35.000000  0.000000    0.0   8.458300
# 75%    1.000000  3.000000  39.750000  0.000000    0.0  51.862500
# max    1.000000  3.000000  54.000000  1.000000    0.0  53.100000

# %%
edades = new_df["Age"]

avg_age = edades.mean(axis=0)
print("Edad promedio:", avg_age)
# Out:
# Edad promedio: 32.385000000000005

# %%
import matplotlib.pyplot as plt

plt.barh(edades.index, edades.values)
plt.show()

# %%
edades.values[3] = avg_age

import matplotlib.pyplot as plt

plt.barh(edades.index, edades.values)
plt.show()

# %%
edades.values
# Out:
# array([26.   , 35.   , 35.   ,    nan, 33.375])

# %% [markdown]
# ### Columna de indices 2do Método(set_index)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#https://www.kaggle.com/c/titanic/data?select=train.csv

file = "titanic-train.csv"
df = pd.read_csv(file)

df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#    Survived  Pclass  ... Cabin Embarked
# 0         0       3  ...   NaN        S
# 1         1       1  ...   C85        C
# 2         1       3  ...   NaN        S
# 3         1       1  ...  C123        S
# 4         0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df.set_index("Name").iloc[:5]
# Out:
#                                                     Survived  ...  Embarked
# Name                                                          ...
# Braund, Mr. Owen Harris                                    0  ...         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  ...         C
# Heikkinen, Miss. Laina                                     1  ...         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1  ...         S
# Allen, Mr. William Henry                                   0  ...         S
#
# [5 rows x 10 columns]

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                                     Survived  ...  Embarked
# Name                                                          ...
# Braund, Mr. Owen Harris                                    0  ...         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  ...         C
# Heikkinen, Miss. Laina                                     1  ...         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1  ...         S
# Allen, Mr. William Henry                                   0  ...         S
# ...                                                      ...  ...       ...
# Montvila, Rev. Juozas                                      0  ...         S
# Graham, Miss. Margaret Edith                               1  ...         S
# Johnston, Miss. Catherine Helen "Carrie"                   0  ...         S
# Behr, Mr. Karl Howell                                      1  ...         C
# ...

# %% [markdown]
# ### Columna de indices 3er Método (read index_col)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#https://www.kaggle.com/c/titanic/data?select=train.csv

file = "titanic-train.csv"
df = pd.read_csv(file, index_col="Name")

df.head()
# Out:
#                                                     PassengerId  ...  Embarked
# Name                                                             ...
# Braund, Mr. Owen Harris                                       1  ...         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  ...         C
# Heikkinen, Miss. Laina                                        3  ...         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4  ...         S
# Allen, Mr. William Henry                                      5  ...         S
#
# [5 rows x 11 columns]

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#                                                     Survived  ...  Embarked
# Name                                                          ...
# Braund, Mr. Owen Harris                                    0  ...         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1  ...         C
# Heikkinen, Miss. Laina                                     1  ...         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1  ...         S
# Allen, Mr. William Henry                                   0  ...         S
#
# [5 rows x 10 columns]

# %%
df.eval("Age >= 30")
# Out:
# Name
# Braund, Mr. Owen Harris                                False
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)     True
# Heikkinen, Miss. Laina                                 False
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            True
# Allen, Mr. William Henry                                True
#                                                        ...
# Montvila, Rev. Juozas                                  False
# Graham, Miss. Margaret Edith                           False
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                  False
# Dooley, Mr. Patrick                                     True
# Name: Age, Length: 891, dtype: bool

# %%
df.Age < 30
# Out:
# Name
# Braund, Mr. Owen Harris                                 True
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    False
# Heikkinen, Miss. Laina                                  True
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           False
# Allen, Mr. William Henry                               False
#                                                        ...
# Montvila, Rev. Juozas                                   True
# Graham, Miss. Margaret Edith                            True
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                   True
# Dooley, Mr. Patrick                                    False
# Name: Age, Length: 891, dtype: bool

# %%
edad_M_30 = df[df.Age < 30]
edad_M_30
# Out:
#                                                    Survived  ...  Embarked
# Name                                                         ...
# Braund, Mr. Owen Harris                                   0  ...         S
# Heikkinen, Miss. Laina                                    1  ...         S
# Palsson, Master. Gosta Leonard                            0  ...         S
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  ...         S
# Nasser, Mrs. Nicholas (Adele Achem)                       1  ...         C
# ...                                                     ...  ...       ...
# Banfield, Mr. Frederick James                             0  ...         S
# Sutehall, Mr. Henry Jr                                    0  ...         S
# Montvila, Rev. Juozas                                     0  ...         S
# Graham, Miss. Margaret Edith                              1  ...         S
# Behr, Mr. Karl Howell                                     1  ...         C
#
# ...

# %%
edad_M_30.drop(["Embarked"], axis=1)
# Out:
#                                                    Survived  ...  Cabin
# Name                                                         ...
# Braund, Mr. Owen Harris                                   0  ...    NaN
# Heikkinen, Miss. Laina                                    1  ...    NaN
# Palsson, Master. Gosta Leonard                            0  ...    NaN
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  ...    NaN
# Nasser, Mrs. Nicholas (Adele Achem)                       1  ...    NaN
# ...                                                     ...  ...    ...
# Banfield, Mr. Frederick James                             0  ...    NaN
# Sutehall, Mr. Henry Jr                                    0  ...    NaN
# Montvila, Rev. Juozas                                     0  ...    NaN
# Graham, Miss. Margaret Edith                              1  ...    B42
# Behr, Mr. Karl Howell                                     1  ...   C148
#
# [384 rows x 9 columns]
